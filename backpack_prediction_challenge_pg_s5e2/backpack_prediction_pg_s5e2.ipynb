# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#    🎒 Backpack Prediction Challenge
# </h1>
#
# <p align="center">
#     <img src="https://media.officedepot.com/image/upload/f_auto,c_limit,w_1920,q_auto/CREATIVE/CREATIVE_2024/SITE/WWW/GLOBAL/2024_WWW_GLOBAL/IMAGES/1525x625-backpacks-header" alt="Backpacks" style="border-radius:10px; max-width:80%;">
# </p>
#
#
# <p style="color:#333; font-family:Verdana">
#     <strong style="color:#0a0a0a;">Goal</strong> - The objective of this challenge is to <strong style="color:#E74C3C;">predict the price of backpacks</strong> given various attributes.
# </p>
# <p style="color:#333; font-family:Verdana">
#     The dataset for this competition (both train and test) was generated from a deep learning model trained on the Student
#     <a href="https://www.kaggle.com/datasets/souradippal/student-bag-price-prediction-dataset" style="color:#2980B9; text-decoration:none; font-weight:bold;">
#         Bag Price Prediction Dataset
#     </a> dataset. Feature distributions are close to, but not exactly the same as the original.
# </p>
# <p style="color:#333; font-family:Verdana">
#     Kaggle competition:
#     <a href="https://www.kaggle.com/competitions/playground-series-s5e2/overview" style="color:#2980B9; text-decoration:none; font-weight:bold;">
#         Backpack Prediction Challenge
#     </a>
# </p>
#
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
# <p style="text-align:center; font-family:Arial; color:#0a0a0a; font-weight:bold; font-size:1.2em;">Files</p>
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
#
# <ul style="color:#333; font-family:Verdana, sans-serif; line-height:1.5;">
#     <li>train.csv - the training dataset; Price is the target</li>
#     <li>train_extra.csv - a whole lot more training data!</li>
#     <li>test.csv -  the test dataset; your objective is to predict the Price for each row</li>
#     <li>sample_submission.csv - a sample submission file in the correct format</li>
# </ul>
#
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
# <p style="text-align:center; font-family:Arial; color:#0a0a0a; font-weight:bold; font-size:1.2em;">Target and evaluation</p>
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
#
# <p style="color:#34495E; font-family:Verdana">
#     The evaluation metric for this challenge is
#     <strong style="color:#E74C3C;">Root Mean Squared Error (RMSE)</strong>.
# </p>
# <p style="color:#34495E; font-family:Verdana">
#     The target variable is <strong style="color:#E74C3C;">Price</strong>.
# </p>
#
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
# <p style="text-align:center; font-family:Arial; color:#0a0a0a; font-weight:bold; font-size:1.2em;">Description of variablesn</p>
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
#
# <table style="width:100%; border-collapse:collapse; font-family:Verdana, sans-serif;">
#     <tr style="background-color:#2C2C54; color:white;">
#         <th style="padding:10px; text-align:left;">Column Name</th>
#         <th style="padding:10px; text-align:left;">Data Type</th>
#         <th style="padding:10px; text-align:center;">Description</th>
#         <th style="padding:10px; text-align:center;">Example Value</th>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Brand</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The brand of the bag</td>
#         <td style="padding:10px; border:1px solid #ddd;">Under Armour, Adidas, Nike, Puma, Jansport</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Material</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The primary material used</td>
#         <td style="padding:10px; border:1px solid #ddd;">Polyester, Leather, Nylon, Canvas</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Size</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The size of the bag</td>
#         <td style="padding:10px; border:1px solid #ddd;">Medium, Large, Small</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Compatments</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The number of compartments in the bag</td>
#         <td style="padding:10px; border:1px solid #ddd;">1 to 10</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Laptop Compartment</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">Whether the bag has a laptop compartment</td>
#         <td style="padding:10px; border:1px solid #ddd;">Yes, No</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Waterproof</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">Whether the bag is waterproof</td>
#         <td style="padding:10px; border:1px solid #ddd;">Yes, No</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Style</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The style of the bag</td>
#         <td style="padding:10px; border:1px solid #ddd;">Messenger, Tote, Backpack</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Color</td>
#         <td style="padding:10px; border:1px solid #ddd;">Categorical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The color of the bag</td>
#         <td style="padding:10px; border:1px solid #ddd;">Pink, Gray, Blue, Red, Black, Green</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Weight Capacity (kg)</td>
#         <td style="padding:10px; border:1px solid #ddd;">Numerical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The maximum weight the bag can hold</td>
#         <td style="padding:10px; border:1px solid #ddd;">11.611723</td>
#     </tr>
#     <tr>
#         <td style="padding:10px; border:1px solid #ddd;">Price</td>
#         <td style="padding:10px; border:1px solid #ddd;">Numerical</td>
#         <td style="padding:10px; border:1px solid #ddd;">The price of the bag in USD</td>
#         <td style="padding:10px; border:1px solid #ddd;">112.15875</td>
#     </tr>
# </table>
#
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
# <p style="text-align:center; font-family:Arial; color:#0a0a0a; font-weight:bold; font-size:1.2em;">Research Plan</p>
# <hr style="border:none; height:2px; background-color:#2C2C54; margin:20px 0;">
#
# <ul style="color:#333; font-family:Verdana, sans-serif; line-height:1.5;">
#     <li>Data Exploration</li>
#     <li>Data Preprocessing</li>
#     <li>Exploratory Data Analysis</li>
#     <li>Correlation Analysis</li>
#     <li>Learning</li>
#     <li>Make predictions on Test Dataset</li>
#     <li>General Conclusion</li>
# </ul>

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     🗂️ Data Exploration
# </h1>

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Import libraries
# </h2>

# %% [markdown]
# <div style="background-color:#e7f3fe; border-left:5px solid #2196F3; padding:10px; font-family:Arial;">
#     <strong>Note:</strong> Make sure to install required library versions before running this notebook. Use <code>pip install</code>.
# </div>

# %%
# !pip install lightgbm==4.4.0 matplotlib==3.7.1 numpy==1.26.4
# !pip install optuna==3.6.1 pandas==2.1.4 phik==0.12.4
# !pip install scikit-learn==1.5.2 scipy==1.10.1 seaborn==0.13.2 
# !pip install scipy==1.10.1 seaborn==0.13.2

# %% [markdown]
# <div style="background-color:#e7f3fe; border-left:5px solid #2196F3; padding:10px; font-family:Arial;">
#     <strong>Note:</strong> In this work, RAPIDS cuDF was used to speed up the calculations, and target encoder from RAPIDS cuML was also used. How to install it you can see in the
#     <a href="https://rapids.ai/cudf-pandas/" style="color:#2980B9; text-decoration:none; font-weight:bold;">
#         documentation
#     </a> or use this
#     <a href="https://www.kaggle.com/code/cdeotte/rapids-cudf-25-02-cuml-25-02" style="color:#2980B9; text-decoration:none; font-weight:bold;">
#         notebook
#     </a> for installation
# </div>

# %%
import os
import warnings 
from itertools import combinations

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from scipy.stats import normaltest, pearsonr

from sklearn.preprocessing import OneHotEncoder, StandardScaler, TargetEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import root_mean_squared_error, mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import PredictionErrorDisplay

import phik
from phik.report import plot_correlation_matrix

from lightgbm import LGBMRegressor, log_evaluation, early_stopping

import optuna
from optuna import distributions
from optuna.exceptions import ExperimentalWarning
import optuna.visualization.matplotlib as vis_matplotlib

# %%
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None
warnings.simplefilter('ignore', UserWarning)
warnings.simplefilter('ignore', FutureWarning)
warnings.simplefilter('ignore', ExperimentalWarning)
warnings.simplefilter('ignore', RuntimeWarning)

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Constants
# </h2>

# %%
TEST_SIZE = 0.25
RANDOM_STATE = 42
ALPHA = 0.05
PTH_TRAIN = r"C:\Users\stepa\Downloads\train.csv"
PTH_TEST = r"C:\Users\stepa\Downloads\test.csv"
PTH_SUB = r"C:\Users\stepa\Downloads\sample_submission.csv"

# Аfter some time another set was added
PTH_TRAINEX = r"C:\Users\stepa\Downloads\training_extra.csv"

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#     Loading data
# </h2>

# %%
if os.path.exists(PTH_TRAIN):
    train_df = pd.read_csv(PTH_TRAIN)
else:
    print('File not found')

# %%
print("Train shape",train_df.shape)
# Out:
# Train shape (300000, 11)

# %%
if os.path.exists(PTH_TRAINEX):
    trainex_df = pd.read_csv(PTH_TRAINEX)
else:
    print('File not found')

# %%
print("Extra Train shape",trainex_df.shape)
# Out:
# Extra Train shape (3694318, 11)

# %%
train_df = pd.concat([train_df, trainex_df], axis=0).reset_index(drop=True)

# %%
print("Combined Train shape",train_df.shape)
# Out:
# Combined Train shape (3994318, 11)

# %%
train_df.head()
# Out:
#    id         Brand Material    Size  Compartments Laptop Compartment  \
# 0   0      Jansport  Leather  Medium           7.0                Yes
# 1   1      Jansport   Canvas   Small          10.0                Yes
# 2   2  Under Armour  Leather   Small           2.0                Yes
# 3   3          Nike    Nylon   Small           8.0                Yes
# 4   4        Adidas   Canvas  Medium           1.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)      Price
# 0         No       Tote  Black             11.611723  112.15875
# 1        Yes  Messenger  Green             27.078537   68.88056
# 2         No  Messenger    Red             16.643760   39.17320
# 3         No  Messenger  Green             12.937220   80.60793
# 4        Yes  Messenger  Green             17.749338   86.02312

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3994318 entries, 0 to 3994317
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Brand                 object
#  2   Material              object
#  3   Size                  object
#  4   Compartments          float64
#  5   Laptop Compartment    object
#  6   Waterproof            object
#  7   Style                 object
#  8   Color                 object
#  9   Weight Capacity (kg)  float64
#  10  Price                 float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 335.2+ MB

# %%
train_df.describe()
# Out:
#                  id  Compartments  Weight Capacity (kg)         Price
# count  3.994318e+06  3.994318e+06          3.992510e+06  3.994318e+06
# mean   2.182137e+06  5.434740e+00          1.801042e+01  8.136217e+01
# std    1.178058e+06  2.893043e+00          6.973969e+00  3.893868e+01
# min    0.000000e+00  1.000000e+00          5.000000e+00  1.500000e+01
# 25%    1.198579e+06  3.000000e+00          1.206896e+01  4.747002e+01
# 50%    2.197158e+06  5.000000e+00          1.805436e+01  8.098495e+01
# 75%    3.195738e+06  8.000000e+00          2.398751e+01  1.148550e+02
# max    4.194317e+06  1.000000e+01          3.000000e+01  1.500000e+02

# %%
if os.path.exists(PTH_TEST):
    test_df = pd.read_csv(PTH_TEST)
else:
    print('File not found')

# %%
print("Test shape",test_df.shape)
# Out:
# Test shape (200000, 10)

# %%
test_df.head()
# Out:
#        id   Brand Material    Size  Compartments Laptop Compartment  \
# 0  300000    Puma  Leather   Small           2.0                 No
# 1  300001    Nike   Canvas  Medium           7.0                 No
# 2  300002  Adidas   Canvas   Large           9.0                 No
# 3  300003  Adidas    Nylon   Large           1.0                Yes
# 4  300004     NaN    Nylon   Large           2.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)
# 0         No       Tote  Green             20.671147
# 1        Yes   Backpack  Green             13.564105
# 2        Yes  Messenger   Blue             11.809799
# 3         No  Messenger  Green             18.477036
# 4        Yes       Tote  Black              9.907953

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    200000 non-null  int64
#  1   Brand                 193773 non-null  object
#  2   Material              194387 non-null  object
#  3   Size                  195619 non-null  object
#  4   Compartments          200000 non-null  float64
#  5   Laptop Compartment    195038 non-null  object
#  6   Waterproof            195189 non-null  object
#  7   Style                 194847 non-null  object
#  8   Color                 193215 non-null  object
#  9   Weight Capacity (kg)  199923 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 15.3+ MB

# %%
test_df.describe()
# Out:
#                   id   Compartments  Weight Capacity (kg)
# count  200000.000000  200000.000000         199923.000000
# mean   399999.500000       5.442855             17.993033
# std     57735.171256       2.888740              6.972079
# min    300000.000000       1.000000              5.000000
# 25%    349999.750000       3.000000             12.068875
# 50%    399999.500000       5.000000             18.054750
# 75%    449999.250000       8.000000             23.965700
# max    499999.000000      10.000000             30.000000

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     📊 Data Preprocessing
# </h1>

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
#     In this section we will data preprocessing, check the data for duplicates and missing values
# </div>

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Check for obvious duplicates
# </h2>

# %%
print(f'duplicate in train: {train_df.duplicated().sum()}')
print(f'duplicate in test: {test_df.duplicated().sum()}')
# Out:
# duplicate in train: 0
# duplicate in test: 0

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Check for implicit duplicates
# </h2>

# %%
cat_cols = train_df.select_dtypes(include='object').columns.to_list()

# %%
for column in cat_cols:
    print(f'Frequency category in {column}')
    print(train_df[column].value_counts())
    print('#' * 10)
# Out:
# Frequency category in Brand
# Brand
# Under Armour    801035
# Adidas          797000
# Nike            764407
# Puma            755778
# Jansport        749340
# Name: count, dtype: int64
# ##########
# Frequency category in Material
# Material
# Polyester    1060882
# Leather       976186
# Nylon         942656
# Canvas        903632
# Name: count, dtype: int64
# ##########
# Frequency category in Size
# Size
# Medium    1354487
# Large     1312295
# Small     1239751
# Name: count, dtype: int64
# ##########
# Frequency category in Laptop Compartment
# Laptop Compartment
# Yes    1972937
# No     1922848
# Name: count, dtype: int64
# ##########
# Frequency category in Waterproof
# Waterproof
# Yes    1969205
# No     1930789
# Name: count, dtype: int64
# ##########
# Frequency category in Style
# Style
# Messenger    1329677
# Tote         1297942
# Backpack     1262519
# Name: count, dtype: int64
# ##########
# Frequency category in Color
# Color
# Pink     688257
# ...

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Check for missing data
# </h2>

# %%
def count_missing(data):
    '''
    The function counts the number of missing values
    in a dataframe, as well as their share relative 
    to all values. Creates a dataframe with two columns. 
    The first is Missing, the second is Share
    args:
        data (DataFrame): the dataframe in which missing 
                          values need to be calculated
    returns:
        data (DataFrame): final dataframe
    '''

    count_na = pd.Series(data.isna().sum(), name='missing')
    proport_na = pd.Series(
        round((data.isna().sum()/len(data)) * 100, 2), name='proportion')

    return pd.concat([count_na, proport_na], axis=1).sort_values(by='proportion', ascending=False)

# %%
count_missing(train_df)
# Out:
#                       missing  proportion
# Color                  133617        3.35
# Brand                  126758        3.17
# Material               110962        2.78
# Style                  104180        2.61
# Laptop Compartment      98533        2.47
# Waterproof              94324        2.36
# Size                    87785        2.20
# Weight Capacity (kg)     1808        0.05
# id                          0        0.00
# Compartments                0        0.00
# Price                       0        0.00

# %%
count_missing(test_df)
# Out:
#                       missing  proportion
# Color                    6785        3.39
# Brand                    6227        3.11
# Material                 5613        2.81
# Style                    5153        2.58
# Laptop Compartment       4962        2.48
# Waterproof               4811        2.41
# Size                     4381        2.19
# Weight Capacity (kg)       77        0.04
# id                          0        0.00
# Compartments                0        0.00

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     📈 Exploratory Data Analysis
# </h1>

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
#     In this section, we analyze numerical and categorical features, and fill in missing values. For numerical features, we conducted a statistical test to check for normality.
# </div>

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Numeric variables
# </h2>

# %%
num_cols = train_df.select_dtypes(include='float').columns.to_list()

# %%
plt.figure(figsize=(15, 10))

plt.suptitle('Distribution',  fontsize=18, fontweight='bold')

for idx, column in enumerate(num_cols, 1):
    plt.subplot(2, 3, idx)
    if idx==1:
        sns.countplot(data=train_df, x=column, palette='pastel')
    else:
        sns.histplot(data=train_df, x=column, bins=40)
    plt.title(f'Distribution of {column}')

    plt.subplot(2, 3, idx+3)
    sns.boxplot(x=train_df[column], width=.1)
    plt.title(f'Boxplot of {column}')

# %%
def test_normal(data):
    '''
    The function tests the data for normal distribution
    using the D'Agostino test. Takes a column and compares
    its p-value with the statistical significance level, 
    outputs a response about normality
    args:
        data (DataFrame): dataframe column
        alpha (float): significance level
    return:
        None
    '''
    
    stat, p = normaltest(data)
    
    if p > ALPHA:
        print('We do not reject H0. The data is from a normal distribution')
    else:
        print('We reject H0 and accept H1. \
The data is not from a normal distribution.')

# %% [markdown]
# Let's make sure that the data is not normally distributed. To do this, we will use the D'Agostino test and formulate hypotheses.
#
# - **H0** - The data is obtained from a normal distribution
# - **H1** - The data is not obtained from a normal distribution
#
# Assuming that **H0** is true, then

# %%
for column in num_cols:
    print(f'Check column {column}')
    test_normal(train_df[column])
    print('#'*10)
    print()
# Out:
# Check column Compartments
# We reject H0 and accept H1. The data is not from a normal distribution.
# ##########
#
# Check column Weight Capacity (kg)
# We reject H0 and accept H1. The data is not from a normal distribution.
# ##########
#
# Check column Price
# We reject H0 and accept H1. The data is not from a normal distribution.
# ##########

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Categorical variables
# </h2>

# %%
def pie_bar_plot(df, col):
    
    data = df[col].value_counts()
    
    plt.figure(figsize=(15, 10))
    
    plt.subplot(2, 2, 1)
    plt.pie(data.values, labels=data.index, autopct='%.1f%%', colors=mcolors.TABLEAU_COLORS)
    plt.title(f'Pie chart of {col}')
    
    plt.subplot(2, 1, 2)
    data.plot(kind='bar', color=mcolors.TABLEAU_COLORS)
    plt.ylabel('count')
    plt.title(f'Barplot of {col}')
    
    plt.subplot(2, 2, 2)
    tableau_palette = list(mcolors.TABLEAU_COLORS.values())
    sns.set_palette(tableau_palette)
    sns.boxplot(x=df['Price'], y=df[col], width=.1, hue=df[col], legend=False)
    plt.title(f'Boxplot of {col}')

# %%
for column in cat_cols:
    pie_bar_plot(train_df, column)

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Analysis and filling of missing values
# </h2>

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
#     Let's analyze whether there is a relationship between the missing values and the other categories. Perhaps the missing values should be left and filled with a placeholder
# </div>

# %%
data_na = train_df.copy()

# %%
def analysis_nan(df, col):

    group_na = data_na.groupby(col)['Price'].agg('mean')
    mode_value = data_na[col].mode()[0]

    plt.figure(figsize=(10, 5))

    plt.bar(group_na.index, group_na.values, color='b')
    plt.ylim(78, 83)
    plt.bar(['NaN'], data_na[data_na[col].isna() == True]
            ['Price'].mean(), color='red', label='NaN')

    plt.bar([f'Mode NaN {mode_value}'], data_na[[col, 'Price']].fillna(mode_value)[
            data_na[col] == mode_value]['Price'].mean(), color='green', label=f'Mode NaN {mode_value}')

    list_cat = group_na.index.to_list()
    list_cat.extend(['NaN', f'Mode NaN {mode_value}'])
    mode_list = [group_na[mode_value]] * (len(group_na)+2)
    plt.plot(list_cat, mode_list, color='orange',
             linestyle='--', label='Mean mode value')
    
    plt.title(f'Average price - {col}')
    plt.ylabel('Average price')
    plt.xlabel(f'{col}')
    plt.legend()
    plt.show()

# %%
for column in cat_cols:
    analysis_nan(data_na, column)

# %%
df = pd.DataFrame({
    'Weight Capacity (kg)': pd.cut(data_na['Weight Capacity (kg)'], 10),
    'Price': data_na['Price']
})

s = df.groupby('Weight Capacity (kg)', observed=True, dropna=False).agg('mean').reset_index()
plt.figure(figsize=(10, 5))
plt.ylim(55, 83)
plt.plot(s[:-1]['Price'], 'bo-', label='non-nan')
plt.bar(10, s.iloc[-1]['Price'], color='red', label='nan')
plt.xlabel('Weight Capacity (kg)'); plt.ylabel('Price')
plt.legend(loc='upper right'); plt.show()

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
#     During the analysis it became clear that it is better to fill in the missing values as separate categories
# </div>

# %%
def feature_enginer(df):
    '''
    The function takes a dataframe and fills in the missing values in each column.
    For numeric data, this is median, for categorical data - Unknown.
    args: 
        df (DataFrame): original dataframe
    returns:
        df (DataFrame): final datagrame
    '''
    
    data = df.copy()

    data['Weight Capacity (kg)'] = data['Weight Capacity (kg)'].fillna(
        data['Weight Capacity (kg)'].median())

    data['Color'] = data['Color'].fillna('Unknown')
    data['Style'] = data['Style'].fillna('Unknown')
    data['Brand'] = data['Brand'].fillna('Unknown')
    data['Size'] = data['Size'].fillna('Unknown')
    data['Laptop Compartment'] = data['Laptop Compartment'].fillna('Unknown')
    data['Waterproof'] = data['Waterproof'].fillna('Unknown')
    data['Material'] = data['Material'].fillna('Unknown')

    # Creat feature
    #conditions = [
        #(data["Weight Capacity (kg)"] <= 5),
        #(data["Weight Capacity (kg)"] > 5) & (data["Weight Capacity (kg)"] <= 15),
        #(data["Weight Capacity (kg)"] > 15) & (data["Weight Capacity (kg)"] <= 20),
        #(data["Weight Capacity (kg)"] > 20) & (data["Weight Capacity (kg)"] <= 25),
        #(data["Weight Capacity (kg)"] > 25)]
    
    #choices = ['Light', 'Middle', 'Light_heavy', 'Middle_heavy', 'Heavy']
    #data['Weight_Class'] = np.select(conditions, choices, default='')

    #data['sin_weight'] = np.sin(data['Weight Capacity (kg)'])
    #data['cos_weight'] = np.cos(data['Weight Capacity (kg)'])
    #data['tan_weight'] = np.tan(data['Weight Capacity (kg)'])
    #data['arcsin_weight'] = np.arcsin(np.clip(data['Weight Capacity (kg)'], -1, 1))
    #data['arccos_weight'] = np.arccos(np.clip(data['Weight Capacity (kg)'], -1, 1))
    #data['arctan_weight'] = np.arctan(data['Weight Capacity (kg)'])

    #data['weight_squared'] = data['Weight Capacity (kg)']**2

    return data

# %%
train_total = feature_enginer(train_df)

# %%
test_total = feature_enginer(test_df)

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     📉 Correlation Analysis
# </h1>

# %%
# Calculate the correlation coefficient Phi
phik_matrix = train_total.drop(columns='id', axis=1).sample(100000).phik_matrix(
    interval_cols=['Weight Capacity (kg)', 'Price'])

# %%
plot_correlation_matrix(phik_matrix.values, x_labels=phik_matrix.columns, y_labels=phik_matrix.index, vmin=0, vmax=1,
                        color_map='coolwarm', title='Сorrelation $\phi_k$', fontsize_factor=1, figsize=(10, 10))

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     🎓 Learning
# </h1>

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
#     This section shows the results of the best attempt, and also shows the processes by which I obtained the hyperparameters of the model for my best attempt.
#
# To determine the hyperparameters, I used optuna and made predictions on the iced dataset (data that was encoded in the normal way + data encoded using RAPIDS cuML Target Encoder)
#
# Since the EDA input showed that our data is very noisy and there is almost no signal with the target, all because the data was synthesized based on a synthesized data set. Therefore, to improve the result, it is necessary to catch a weak signal in the data and for this, it was necessary to create many new features.
# </div>

# %%
def encoder(df):
    '''
    The function produces encoding of features (Ordinal, Ohe, Standard)
    args:
        df (DataFrame): original dataframe
    returns:
        data (DataFrame): final dataframe
    '''

    data = df.copy()

    # Ordinal encoding
    data['Size'] = data['Size'].replace({'Unknown': 1, 'Small': 2, 'Medium': 3, 'Large': 4})
    data['Weight_Class'] = data['Weight_Class'].replace({'Light': 1, 'Middle': 2, 'Light_heavy': 3,
                                                        'Middle_heavy': 4, 'Heavy': 5})
    
    # OneHot encoding
    data = pd.get_dummies(data, columns=['Material', 'Style', 'Color', 'Brand', 'Waterproof', 'Laptop Compartment'], 
                          prefix=['Material', 'Style', 'Color', 'Brand', 'Waterproof', 'Laptop Compartment'], 
                          drop_first=True, dtype='int')
    
    # Standard scaler   
    data['Weight Capacity (kg)'] = (data['Weight Capacity (kg)'] -
                                    data['Weight Capacity (kg)'].mean()) / data['Weight Capacity (kg)'].std()

    return data

# %%
train_sc = encoder(train_total)
test_sc = encoder(test_total)
test_sc = test_sc.drop(columns='id', axis=1)

# %%
y = train_sc['Price']
X = train_sc.drop(columns=['id', 'Price'], axis=1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE
)

# %%
print('Size of train', X_train.shape, y_train.shape)
print('Size of valid', X_valid.shape, y_valid.shape)
# Out:
# Size of train (2995738, 26) (2995738,)
# Size of valid (998580, 26) (998580,)

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Dummy model
# </h2>

# %%
dm_model = DummyRegressor(strategy='mean')
dm_model.fit(X_train, y_train)
pred_dm = dm_model.predict(X_valid)
rmse = root_mean_squared_error(y_valid, pred_dm)

print(f'RMSE: {rmse:.5f}')
# Out:
# RMSE: 39.02421

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    RAPIDS cuML TE + Data Encoder and LGBM with optuna
# </h2>

# %%
import cuml
from cuml.preprocessing import TargetEncoder

# %%
TE = TargetEncoder(n_folds=25, smooth=20, split_method='random', stat='mean')

train_te_r = pd.DataFrame()
test_te_r = pd.DataFrame()
g = y.to_list()

for col in X.columns.to_list():
    f = np.array(X[col]).reshape(-1, 1)
    t = np.array(test_sc[col]).reshape(-1, 1)
    X_te = TE.fit_transform(f, g)
    train_te_r[f'TE_{col}'] = pd.DataFrame(X_te)
    t_te = TE.transform(t)
    test_te_r[f'TE_{col}'] = pd.DataFrame(t_te)

# %%
from sklearn.metrics import PredictionErrorDisplay

# %%
train_te_sc = pd.concat([train_sc, train_te_r], axis=1)
test_te_sc = pd.concat([test_sc, test_te_r], axis=1)

# %%
X = train_te_sc.drop(columns='Price', axis=0)
y = train_te_sc['Price']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X,
    y,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE
)

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "num_leaves": trial.suggest_int("num_leaves", 50, 250),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1)
    }
    
    model = LGBMRegressor(**params, verbose=-1, random_state=RANDOM_STATE)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    
    return root_mean_squared_error(y_valid, y_pred)

# %%
study = optuna.create_study(study_name='LGBM_TE_RP', direction='minimize')
optuna.logging.set_verbosity(optuna.logging.WARNING)
study.optimize(objective, n_trials=10, show_progress_bar=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
print('Best parameters: ', study.best_params)
# Out:
# Best parameters:  {'n_estimators': 451, 'max_depth': 8, 'num_leaves': 233, 'learning_rate': 0.03000044687948457, 'min_child_samples': 62, 'subsample': 0.9694010630437035, 'colsample_bytree': 0.5645494636160868, 'reg_alpha': 0.564820643502276, 'reg_lambda': 0.4346072158112042}

# %%
vis_matplotlib.plot_optimization_history(study)
plt.show()

vis_matplotlib.plot_slice(study)
plt.show()

vis_matplotlib.plot_param_importances(study)
plt.show()

# %%
lgbm = LGBMRegressor(**study.best_params, n_jobs=-1, verbose=-1, random_state=RANDOM_STATE)
lgbm.fit(X, y)
# Out:
# LGBMRegressor(colsample_bytree=0.5645494636160868,
#               learning_rate=0.03000044687948457, max_depth=8,
#               min_child_samples=62, n_estimators=451, n_jobs=-1, num_leaves=233,
#               random_state=42, reg_alpha=0.564820643502276,
#               reg_lambda=0.4346072158112042, subsample=0.9694010630437035,
#               verbose=-1)

# %%
y_pred = lgbm.predict(test_te_sc)

# %%
y_pred_t = lgbm.predict(X)

# %%
display = PredictionErrorDisplay(y_true=y, y_pred=y_pred_t)
display.plot()
plt.show()

# %% [markdown]
# <h2 style="color:#40407A; font-family:'Courier New', monospace;">
#    Feature select
# </h2>

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
# We will check all possible combinations of features and determine the best ones, so that we can use them in the future.
#
# </div>

# %%
# %%time

# Categorical features
cat_features = ['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment', 'Waterproof', 'Style', 'Color']

# Maximum number of features in a combination
max_features = 6

# List to save results
results = []

# Searching for all combinations from 2 to max_features
for r in range(2, max_features+1):
    for combo in combinations(cat_features, r):
        # Create a new column title
        new_col_name = '_'.join(combo)

        train_new_col = train_total.copy()
        
        # Combining features
        train_new_col[new_col_name] = train_new_col[list(combo)].astype(str).agg('_'.join, axis=1)
        
        # We encode categorical features
        X = train_new_col[new_col_name].factorize()[0].reshape(-1, 1)
        y = train_new_col['Price']  # Target variable
        
        # We divide into train and test
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)
        
        # Training the model
        model = Ridge()
        model.fit(X_train, y_train)
        
        # We evaluate the result
        y_pred = model.predict(X_test)
        score = mean_squared_error(y_test, y_pred)
        
        # We save the combination and its evaluation
        results.append((combo, score))
        print(f"Combination: {combo} with MSE: {score}")

# Sort by score (MSE) and select top 20
top_20_combos = sorted(results, key=lambda x: x[1])[:20]

print("\nTop-20 Combinations:")
for combo, score in top_20_combos:
    print(f"Combination: {combo}, MSE: {score}")
# Out:
# Combination: ('Brand', 'Material') with MSE: 1513.5084954639535
# Combination: ('Brand', 'Size') with MSE: 1513.5062031343018
# Combination: ('Brand', 'Compartments') with MSE: 1513.524715718154
# Combination: ('Brand', 'Laptop Compartment') with MSE: 1513.4899125269424
# Combination: ('Brand', 'Waterproof') with MSE: 1513.4392785925504
# Combination: ('Brand', 'Style') with MSE: 1513.5212422512586
# Combination: ('Brand', 'Color') with MSE: 1513.5176544515884
# Combination: ('Material', 'Size') with MSE: 1513.5096324964693
# Combination: ('Material', 'Compartments') with MSE: 1513.5281501793245
# Combination: ('Material', 'Laptop Compartment') with MSE: 1513.5258660630298
# Combination: ('Material', 'Waterproof') with MSE: 1513.5184416237703
# Combination: ('Material', 'Style') with MSE: 1513.5041655127852
# Combination: ('Material', 'Color') with MSE: 1513.5148063670304
# Combination: ('Size', 'Compartments') with MSE: 1513.5205926334697
# ...

# %% [markdown]
# <div style="background-color:#f9f9f9; border-left:5px solid #40407A; padding:10px; font-family:Verdana, sans-serif; color:#333;">
#     Next we will design features using groupby(COL1)[COL2].agg(STAT). This is where we group by the COL1 columns and aggregate (i.e. calculate) the STAT statistics on another column COL2. This is the basic method used to calculate target encoding and count encoding. By calculating the raw statistics groupby(COL1)[COL2].agg(STAT) and feeding it into our model.
# </div>

# %%
CATS = list(train_total.columns[1:-2])
print(f"There are {len(CATS)} categorical columns:")
print( CATS )
print(f"There are 1 numerical column:")
print( ["Weight Capacity (kg)"] )
# Out:
# There are 8 categorical columns:
# ['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment', 'Waterproof', 'Style', 'Color']
# There are 1 numerical column:
# ['Weight Capacity (kg)']

# %%
for list_col, _ in top_20_combos[:10]:
    new_col_name = '_'.join(list_col)
    train_total[new_col_name] = train_total[list(list_col)].astype('str').agg('_'.join, axis=1)
    test_total[new_col_name] = test_total[list(list_col)].astype('str').agg('_'.join, axis=1)
    CATS.append(new_col_name)

# %%
COMBO = []
for i,c in enumerate(CATS):
    combine = pd.concat([train_total[c],test_total[c]],axis=0)
    combine,_ = pd.factorize(combine)
    train_total[c] = combine[:len(train_total)]
    test_total[c] = combine[len(train_total):]
    n = f"{c}_wc"
    train_total[n] = train_total[c]*100 + train_total["Weight Capacity (kg)"]
    test_total[n] = test_total[c]*100 + test_total["Weight Capacity (kg)"]
    COMBO.append(n)
print()
print(f"We engineer {len(COMBO)} new columns!")
print( COMBO )
# Out:
# We engineer 18 new columns!
# ['Brand_wc', 'Material_wc', 'Size_wc', 'Compartments_wc', 'Laptop Compartment_wc', 'Waterproof_wc', 'Style_wc', 'Color_wc', 'Size_Laptop Compartment_Waterproof_Style_wc', 'Material_Size_Compartments_Laptop Compartment_Waterproof_Color_wc', 'Brand_Size_Compartments_Laptop Compartment_Waterproof_Color_wc', 'Brand_Size_Laptop Compartment_Waterproof_Style_Color_wc', 'Brand_Size_Compartments_Laptop Compartment_Waterproof_wc', 'Size_Compartments_Laptop Compartment_Waterproof_Color_wc', 'Brand_Size_Laptop Compartment_Waterproof_Style_wc', 'Material_Size_Laptop Compartment_Waterproof_Style_Color_wc', 'Brand_Size_Compartments_Waterproof_Color_wc', 'Size_Compartments_Laptop Compartment_Waterproof_Style_Color_wc']

# %%
FEATURES = CATS + ["Weight Capacity (kg)"] + COMBO
print(f"We now have {len(FEATURES)} columns:")
print( FEATURES )
# Out:
# We now have 37 columns:
# ...

# %%
# STATISTICS TO AGGEGATE FOR OUR FEATURE GROUPS
STATS = ["mean","std","count","nunique","median","min","max","skew", "var", "sem"]
STATS2 = ["mean","std", "var", "median"]

# %%
col = train_total.columns.to_list()

for c in col[:9]:
    train_total[c] = train_total[c].astype('int32')
    test_total[c] = test_total[c].astype('int32')

for c in col[11:21]:
    train_total[c] = train_total[c].astype('int32')
    test_total[c] = test_total[c].astype('int32')

for c in col[21:]:
    train_total[c] = train_total[c].astype('float32')
    test_total[c] = test_total[c].astype('float32')

# %%
lgbm_params = {'n_estimators': 451, 'max_depth': 8, 'num_leaves': 233, 'learning_rate': 0.03000044687948457, 
               'min_child_samples': 62, 'subsample': 0.9694010630437035, 'colsample_bytree': 0.5645494636160868, 
               'reg_alpha': 0.564820643502276, 'reg_lambda': 0.4346072158112042}

# %%
# %%time

FOLDS = 7
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

oof_train = np.zeros((train_total.shape[0], ))
pred = np.zeros((test_total.shape[0], ))
oof_test_skf = np.empty((FOLDS, test_total.shape[0]))

# OUTER K FOLD
for i, (train_index, valid_index) in enumerate(kf.split(train_total)):
    print(f"### OUTER Fold {i+1} ###")

    X_train = train_total.loc[train_index,FEATURES+['Price']].reset_index(drop=True).copy()
    y_train = train_total.loc[train_index,'Price']

    X_valid = train_total.loc[valid_index,FEATURES].reset_index(drop=True).copy()
    y_valid = train_total.loc[valid_index,'Price']

    X_test = test_total[FEATURES].reset_index(drop=True).copy()

    # INNER K FOLD (TO PREVENT LEAKAGE WHEN USING PRICE)
    kf2 = KFold(n_splits=FOLDS, shuffle=True, random_state=42)   
    for j, (train_index2, valid_index2) in enumerate(kf2.split(X_train)):
        print(f" ## INNER Fold {j+1} (outer fold {i+1}) ##")

        X_train2 = X_train.loc[train_index2,FEATURES+['Price']].copy()
        X_valid2 = X_train.loc[valid_index2,FEATURES].copy()

        ### FEATURE SET 1 (uses price) ###
        col = "Weight Capacity (kg)"
        tmp = X_train2.groupby(col).Price.agg(STATS)
        tmp.columns = [f"TE1_wc_{s}" for s in STATS]
        X_valid2 = X_valid2.merge(tmp, on=col, how="left")
        for c in tmp.columns:
            X_train.loc[valid_index2,c] = X_valid2[c].values

        ### FEATURE SET 2 (uses price) ###
        for col in COMBO:
            tmp = X_train2.groupby(col).Price.agg(STATS2)
            tmp.columns = [f"TE2_{col}_{s}" for s in STATS2]
            X_valid2 = X_valid2.merge(tmp, on=col, how="left")
            for c in tmp.columns:
                X_train.loc[valid_index2,c] = X_valid2[c].values

    ### FEATURE SET 1 (uses price) ###
    col = "Weight Capacity (kg)"
    tmp = X_train.groupby(col).Price.agg(STATS)
    tmp.columns = [f"TE1_wc_{s}" for s in STATS]
    X_valid = X_valid.merge(tmp, on=col, how="left")
    X_test = X_test.merge(tmp, on=col, how="left")
    
    ### FEATURE SET 2 (uses price) ###
    for col in COMBO:
        tmp = X_train.groupby(col).Price.agg(STATS2)
        tmp.columns = [f"TE2_{col}_{s}" for s in STATS2]
        X_valid = X_valid.merge(tmp, on=col, how="left")
        X_test = X_test.merge(tmp, on=col, how="left")

    ### FEATURE SET 3 (does not use price) ###
    for col in CATS:
        col2 = "Weight Capacity (kg)"
        tmp = X_train.groupby(col)[col2].agg(STATS2)
        tmp.columns = [f"FE3_{col}_wc_{s}" for s in STATS2]
        X_train = X_train.merge(tmp, on=col, how="left")
        X_valid = X_valid.merge(tmp, on=col, how="left")
        X_test = X_test.merge(tmp, on=col, how="left")

    # DROP PRICE THAT WAS USED FOR TARGET ENCODING
    X_train = X_train.drop(['Price'],axis=1)

    # BUILD MODEL
    model = LGBMRegressor(**lgbm_params, n_jobs=-1, random_state=RANDOM_STATE, verbose=-1)
    
    # TRAIN MODEL
    COLS = X_train.columns
    model.fit(
        X_train[COLS], y_train,
        eval_set=[(X_valid[COLS], y_valid)],  
        callbacks=[log_evaluation(0), early_stopping(100, verbose=False)])

    # PREDICT OOF AND TEST
    oof_train[valid_index] = model.predict(X_valid[COLS])
    oof_test_skf[i, :] = model.predict(X_test[COLS])

pred[:] = oof_test_skf.mean(axis=0)
# Out:
# ### OUTER Fold 1 ###
#  ## INNER Fold 1 (outer fold 1) ##
#  ## INNER Fold 2 (outer fold 1) ##
#  ## INNER Fold 3 (outer fold 1) ##
#  ## INNER Fold 4 (outer fold 1) ##
#  ## INNER Fold 5 (outer fold 1) ##
#  ## INNER Fold 6 (outer fold 1) ##
#  ## INNER Fold 7 (outer fold 1) ##
# ### OUTER Fold 2 ###
#  ## INNER Fold 1 (outer fold 2) ##
#  ## INNER Fold 2 (outer fold 2) ##
#  ## INNER Fold 3 (outer fold 2) ##
#  ## INNER Fold 4 (outer fold 2) ##
#  ## INNER Fold 5 (outer fold 2) ##
#  ## INNER Fold 6 (outer fold 2) ##
#  ## INNER Fold 7 (outer fold 2) ##
# ### OUTER Fold 3 ###
#  ## INNER Fold 1 (outer fold 3) ##
#  ## INNER Fold 2 (outer fold 3) ##
#  ## INNER Fold 3 (outer fold 3) ##
#  ## INNER Fold 4 (outer fold 3) ##
#  ## INNER Fold 5 (outer fold 3) ##
#  ## INNER Fold 6 (outer fold 3) ##
#  ## INNER Fold 7 (outer fold 3) ##
# ### OUTER Fold 4 ###
#  ## INNER Fold 1 (outer fold 4) ##
#  ## INNER Fold 2 (outer fold 4) ##
#  ## INNER Fold 3 (outer fold 4) ##
# ...

# %%
# COMPUTE OVERALL CV SCORE
true = train_total.Price.values
s = np.sqrt(np.mean((oof_train-true)**2.0))
print(f"=> Overall CV Score = {s}")
# Out:
# => Overall CV Score = 38.65622365572786

# %%
print(f"\nIn total, we used {len(COLS)} features.\n")
print( list(COLS) )
# Out:
# In total, we used 191 features.
#
# ...

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     💡 Make Predictions on Test Dataset
# </h1>

# %%
if os.path.exists(PTH_SUB):
    submission = pd.read_csv(PTH_SUB)
else:
    print('File not found')

# %%
submission['Price'] = pred

# %%
submission.to_csv('submission.csv', index=False)

# %%
plt.figure(figsize=(15, 5))
submission["Price"].plot(
    color='blue', linewidth=0.1, title="Submission | Price Distribution"
)
plt.axhline(submission["Price"].mean(), c="w", ls="-", lw=2.5)
plt.show()

# %% [markdown]
# <h1 style="background-color:#2C2C54; color:white; text-align:center; padding:15px; border-radius:10px; font-family:Arial, sans-serif;">
#     📓 General Conclusion
# </h1>

# %% [markdown]
# <p style="color:#333; font-family:Verdana">
#     As a result of this competition, it was possible to get into the top 3%. Due to the peculiarities of the data (the target has no obvious relationship) due to the fact that this data set was synthesized based on a synthetic data set, and the target (price) was chosen randomly. In this case, it was necessary to generate a signal in order to get a good result. Therefore, it was necessary to resort to creating a large number of features (191) and train one model (LGBMRegressor hyperparameters were determined using optuna).
# </p>
